# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
osteo_data = pd.read_csv(r"C:\Users\KAsab\Desktop\MACHINE LEARNING PROJECTS\osteoporosis_ML_classification\cleaned_survey.csv")

# %%
osteo_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5831 entries, 0 to 5830
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Age                     5831 non-null   float64
#  1   Gender                  5831 non-null   object
#  2   Race                    5831 non-null   object
#  3   BMI                     5831 non-null   float64
#  4   Smoking                 5831 non-null   object
#  5   Heavy Drinking          5831 non-null   object
#  6   Sleep Duration (Hours)  5831 non-null   float64
#  7   Arthritis               5831 non-null   object
#  8   Liver Condition         5831 non-null   object
#  9   Parental Osteoporosis   5831 non-null   object
#  10  Osteoporosis            5831 non-null   object
# dtypes: float64(3), object(8)
# memory usage: 501.2+ KB

# %%
num_vars = osteo_data.select_dtypes(include = "number").columns.to_list()
print(num_vars)
# Out:
# ['Age', 'BMI', 'Sleep Duration (Hours)']

# %%
cat_vars = osteo_data.select_dtypes(include = "object").columns.to_list()
print(cat_vars)
# Out:
# ['Gender', 'Race', 'Smoking', 'Heavy Drinking', 'Arthritis', 'Liver Condition', 'Parental Osteoporosis', 'Osteoporosis']

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer

# %%
osteo_data[num_vars].hist(figsize = (12,8),edgecolor = "white",grid = False)
plt.show()

# %%
[x.value_counts() for x in osteo_data[cat_vars]]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 [x.value_counts() for x in osteo_data[cat_vars]]
#
# AttributeError: 'str' object has no attribute 'value_counts'
